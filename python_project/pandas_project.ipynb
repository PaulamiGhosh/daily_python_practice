# %% [markdown]
# ### Pandas practice notebook

# %%
import pandas as pd
import numpy as np

# %%
# first operation in pandas
# Out:
# hello worl

# %%
print('hello world !!!!')
# Out:
# hello world !!!!
